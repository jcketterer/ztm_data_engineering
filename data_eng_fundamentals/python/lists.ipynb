# %%
#LISTS

hourly_website_visits = [235,213,287,198,305]

hourly_website_visits
# Out:
# [235, 213, 287, 198, 305]

# %%
hourly_website_visits[0]
# Out:
# 235

# %%
hourly_website_visits[1]
# Out:
# 213

# %%
hourly_website_visits[-1]
# Out:
# 305

# %%
len(hourly_website_visits)
# Out:
# 5

# %%
hourly_website_visits[0:3]
# Out:
# [235, 213, 287]

# %%
lst = [True, 1, 'hi']
lst
# Out:
# [True, 1, 'hi']

# %%
for v in hourly_website_visits:
    print('Visits :', v)
# Out:
# Visits : 235
# Visits : 213
# Visits : 287
# Visits : 198
# Visits : 305
