# %%
page_visits_count = {
    '/info': 1458,
    '/search': 73,
    '/order': 5
}

page_visits_count
# Out:
# {'/info': 1458, '/search': 73, '/order': 5}

# %%
page_visits_count['/info']
# Out:
# 1458

# %%
print(page_visits_count.get('/unknown'))
# Out:
# None

# %%
page_visits_count.get('/payments',0)
# Out:
# 0

# %%
for item in page_visits_count.items():
    print(item[0], ' -> ', item[1])
# Out:
# /info  ->  1458
# /search  ->  73
# /order  ->  5

# %%
for page, visits in page_visits_count.items():
    print(page, ' -> ', visits)
# Out:
# /info  ->  1458
# /search  ->  73
# /order  ->  5

# %%
page_visits_count['/contact'] = 20
page_visits_count
# Out:
# {'/info': 1458, '/search': 73, '/order': 5, '/contact': 20}

# %%
visits = [
    ('alice', '/info'),
    ('bob', '/info'),
    ('alice', '/order'),
    ('carol', '/info'),
    ('bob', '/search'),
]

page_counts = {}

for _, page in visits:
    # _ is for variable not used
    page_counts[page] = page_counts.get(page,0) + 1
    
page_counts
# Out:
# {'/info': 3, '/order': 1, '/search': 1}
