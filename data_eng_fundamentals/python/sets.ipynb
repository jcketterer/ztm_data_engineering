# %%
#LIKE TUPLE CANNOT CONTAIN DUPLICATE VALUES

visited_urls = {
    '/info',
    '/order',
    '/search'
}

visited_urls
# Out:
# {'/info', '/order', '/search'}

# %%
visited_urls.add('/search')
visited_urls
# Out:
# {'/info', '/order', '/search'}

# %%
visited_urls.add('/payments')

visited_urls
# Out:
# {'/info', '/order', '/payments', '/search'}

# %%
'/search' in visited_urls
# Out:
# True

# %%
'/unknown' in visited_urls
# Out:
# False
