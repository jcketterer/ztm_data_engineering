# %%
row = ('UK','London',21.6)
row
# Out:
# ('UK', 'London', 21.6)

# %%
print('First :', row[0])
print('Last :', row[-1])
print('Slice :', row[0:2])
# Out:
# First : UK
# Last : 21.6
# Slice : ('UK', 'London')

# %%
#TUPLES CANNOT BE CHANGED OR IMMUTABLE

row.append(1)

#ERROR
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 3
#       1 #TUPLES CANNOT BE CHANGED OR IMMUTABLE
# ----> 3 row.append(1)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
row[1] = 'France'

#THIS WILL ERROR AS
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 row[1] = 'France'
#
# TypeError: 'tuple' object does not support item assignment

# %%
#CREATING TUPLE WITH ONE VALUE 

single_element_tuple = (1,)
not_tuple = (1)

# %%
type(single_element_tuple)
# Out:
# tuple

# %%
type(not_tuple)
# Out:
# int

# %%
#UNPACKING
country, city, temp = ('UK','London',21.6)

print('Country :', country)
print('City :', city)
print('Temperature :', temp)
# Out:
# Country : UK
# City : London
# Temperature : 21.6
